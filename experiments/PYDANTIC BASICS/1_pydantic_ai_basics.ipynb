# %%
def play_game(score:int):
    print("The score is ", score)
    
play_game([45,85,95])
# Out:
# The score is  [45, 85, 95]

# %% [markdown]
# neeed: to control the input

# %% [markdown]
# PYDANTIC MODE ON

# %%
from pydantic import BaseModel

class Player(BaseModel):
    name: str 
    score: int 
    
player1 = Player(name=25,
            score = 100)

print(player1)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[14], line 7
#       3 class Player(BaseModel):
#       4     name: str
#       5     score: int
#       6
# ----> 7 player1 = Player(name=25,
#       8             score = 100)
#       9
#      10 print(player1)
#
# File ~\Downloads\WILLLSSSSSS\Ecommerece Store\pydanticenv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
# ...

# %%
type(Player)
# Out:
# pydantic._internal._model_construction.ModelMetaclass

# %%
#smart data conversion

# %%
a = "100"

type(a)
# Out:
# str

# %%
player2 = Player(name="priya",
            score = "100")

print(player2)
# Out:
# name='priya' score=100

# %%
type(player2)
# Out:
# __main__.Player
